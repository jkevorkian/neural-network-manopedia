# %%
##          DATA SHAPE DEFINITION           ##

import numpy as np

# Define the parameters for the data shape
num_handsigns = 4
videos_per_handsign = 50
frames_per_video = 30
num_landmarks = 51
num_coordinates = 3

# Generate dummy data
data = [np.random.rand(videos_per_handsign, frames_per_video, num_landmarks, num_coordinates) for _ in range(num_handsigns)]

# Convert the list to a numpy array with shape (num_handsigns, videos_per_handsign, frames_per_video, num_landmarks, num_coordinates)
data_array = np.array(data)

# Save the data array to a .npy file
np.save('handsigns_data.npy', data_array)

# %%
import numpy as np

# Function to normalize 3D landmarks based on the head landmark (or any other reference point)
def normalize_landmarks(landmarks, reference_landmark):
    ref_point = landmarks[reference_landmark]  # Use head as the reference point, e.g., head at index X
    normalized_landmarks = [(x - ref_point[0], y - ref_point[1], z - ref_point[2]) for (x, y, z) in landmarks]
    return normalized_landmarks

# Optional function to apply 3D rotation augmentation
def rotate_landmarks(landmarks, angle=0.1):
    rotation_matrix = np.array([
        [np.cos(angle), -np.sin(angle), 0],
        [np.sin(angle), np.cos(angle), 0],
        [0, 0, 1]
    ])
    rotated_landmarks = [np.dot(rotation_matrix, np.array([x, y, z])) for (x, y, z) in landmarks]
    return rotated_landmarks

# Main function to process each frame of video and extract normalized (and optionally rotated) landmarks
def extract_landmarks(image, hands_results, pose_results, apply_rotation=False, rotation_angle=0.1, head_idx=0):
    landmarks = []
    
    # Extract head landmarks (to be used for normalization)
    if pose_results.pose_landmarks:
        head_landmarks = [(lm.x, lm.y, lm.z) for lm in pose_results.pose_landmarks.landmark]
        head_normalized_landmarks = normalize_landmarks(head_landmarks, reference_landmark=head_idx)
    
    # Extract left-hand landmarks (21 landmarks)
    if hands_results.multi_hand_landmarks and len(hands_results.multi_hand_landmarks) > 0:
        left_hand_landmarks = [(lm.x, lm.y, lm.z) for lm in hands_results.multi_hand_landmarks[0].landmark]
        left_hand_landmarks = normalize_landmarks(left_hand_landmarks, reference_landmark=head_idx)
        
        # Apply rotation if the parameter is set to True
        if apply_rotation:
            left_hand_landmarks = rotate_landmarks(left_hand_landmarks, angle=rotation_angle)
        
        landmarks.extend(left_hand_landmarks)
    else:
        landmarks.extend([(0, 0, 0)] * 21)  # Zero padding for missing hand
    
    # Repeat the same for right-hand landmarks
    if hands_results.multi_hand_landmarks and len(hands_results.multi_hand_landmarks) > 1:
        right_hand_landmarks = [(lm.x, lm.y, lm.z) for lm in hands_results.multi_hand_landmarks[1].landmark]
        right_hand_landmarks = normalize_landmarks(right_hand_landmarks, reference_landmark=head_idx)
        
        # Apply rotation if the parameter is set to True
        if apply_rotation:
            right_hand_landmarks = rotate_landmarks(right_hand_landmarks, angle=rotation_angle)
        
        landmarks.extend(right_hand_landmarks)
    else:
        landmarks.extend([(0, 0, 0)] * 21)
    
    # Extract and normalize pose landmarks (excluding head landmark to avoid double counting)
    if pose_results.pose_landmarks:
        pose_landmarks = [(lm.x, lm.y, lm.z) for lm in pose_results.pose_landmarks.landmark if lm != head_landmarks[head_idx]]
        pose_landmarks = normalize_landmarks(pose_landmarks, reference_landmark=head_idx)
        
        if apply_rotation:
            pose_landmarks = rotate_landmarks(pose_landmarks, angle=rotation_angle)
        
        landmarks.extend(pose_landmarks)
    else:
        landmarks.extend([(0, 0, 0)] * 9)  # Zero padding for missing pose landmarks
    
    return landmarks

# Example usage in your video processing loop:
apply_rotation_augmentation = True  # Set this to False to skip rotation augmentation
rotation_angle = 0.1  # Set the desired rotation angle
head_idx = 0  # Set the index of the head landmark (change as per dataset)

# Function to process a single video and extract normalized landmarks
def process_video(video, apply_rotation=False, rotation_angle=0.1, head_idx=0):
    video_landmarks = []
    
    for frame in video.frames:
        image = load_frame(frame)  # Hypothetical function to load the current frame
        hands_results = process_hands(image)  # Process hands using MediaPipe or similar
        pose_results = process_pose(image)    # Process pose using MediaPipe or similar
        
        # Extract landmarks using the updated function
        landmarks = extract_landmarks(image, hands_results, pose_results, apply_rotation, rotation_angle, head_idx)
        video_landmarks.append(landmarks)
    
    return np.array(video_landmarks)  # Return the processed landmarks for this video


for video in video_dataset:
    for frame in video.frames:
        image = load_frame(frame)  # Hypothetical function to load the current frame
        hands_results = process_hands(image)  # Process hands using MediaPipe or similar
        pose_results = process_pose(image)    # Process pose using MediaPipe or similar
        
        landmarks = extract_landmarks(image, hands_results, pose_results, apply_rotation_augmentation, rotation_angle, head_idx)
        # Save or use the landmarks as needed...

# %%
##          PROCESS VIDEO DATASET FUNC DEFINITIONS         ##
import cv2
import mediapipe as mp
import numpy as np
import os
from tqdm import tqdm

def extract_landmarks(image, hands_results, pose_results):
    landmarks = []
    
    # Extract left hand landmarks (21 landmarks)
    if hands_results.multi_hand_landmarks and len(hands_results.multi_hand_landmarks) > 0:
        landmarks.extend([(lm.x, lm.y, lm.z) for lm in hands_results.multi_hand_landmarks[0].landmark])
    else:
        landmarks.extend([(0, 0, 0)] * 21)
    
    # Extract right hand landmarks (21 landmarks)
    if hands_results.multi_hand_landmarks and len(hands_results.multi_hand_landmarks) > 1:
        landmarks.extend([(lm.x, lm.y, lm.z) for lm in hands_results.multi_hand_landmarks[1].landmark])
    else:
        landmarks.extend([(0, 0, 0)] * 21)
    
    # Extract selected body landmarks (9 landmarks)
    selected_body_landmarks = [0, 11, 12, 13, 14, 15, 16, 23, 24]  # Landmarks for nose, arms, and shoulders
    if pose_results.pose_landmarks:
        for idx in selected_body_landmarks:
            lm = pose_results.pose_landmarks.landmark[idx]
            landmarks.append((lm.x, lm.y, lm.z))
    else:
        landmarks.extend([(0, 0, 0)] * 9)
    
    return np.array(landmarks)

def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    
    mp_hands = mp.solutions.hands
    mp_pose = mp.solutions.pose

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    indices = np.linspace(0, total_frames - 1, frames_per_video, dtype=int)
    frame_set = set(indices)
    frame_count = 0
    
    with mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5) as hands, \
         mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        
        while cap.isOpened() and len(frames) < frames_per_video:
            ret, frame = cap.read()
            if not ret:
                break
            
            if frame_count in frame_set:
                # Convert the BGR image to RGB
                image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                
                # Process the image and extract landmarks
                hands_results = hands.process(image)
                pose_results = pose.process(image)
                
                # Extract landmarks
                landmarks = extract_landmarks(image, hands_results, pose_results)
                
                frames.append(landmarks)
            
            frame_count += 1
    
    cap.release()
    
    # Pad if we don't have enough frames
    if len(frames) < frames_per_video:
        frames.extend([np.zeros((51, 3))] * (frames_per_video - len(frames)))
    
    return np.array(frames)

def process_dataset(root_path):
    data = []
    
    for handsign in tqdm(range(num_handsigns), desc="Processing handsigns"):
        handsign_path = os.path.join(root_path, f"handsign_{handsign+1}")  # Changed to match your folder naming
        if not os.path.exists(handsign_path):
            print(f"Warning: Directory {handsign_path} does not exist. Skipping.")
            data.append(np.zeros((videos_per_handsign, frames_per_video, 51, 3)))  # 51 landmarks total
            continue
        
        videos = [f for f in os.listdir(handsign_path) if f.endswith(('.mp4', '.avi', '.mov'))]
        videos = videos[:videos_per_handsign]  # Limit to videos_per_handsign
        
        handsign_data = []
        for video in tqdm(videos, desc=f"Processing videos for handsign {handsign}", leave=False):
            video_path = os.path.join(handsign_path, video)
            video_data = process_video(video_path)
            handsign_data.append(video_data)
        
        # Pad if we don't have enough videos
        if len(handsign_data) < videos_per_handsign:
            handsign_data.extend([np.zeros((frames_per_video, 51, 3))] * (videos_per_handsign - len(handsign_data)))
        
        data.append(np.array(handsign_data))
    
    return np.array(data)

# %%
##          PROCESS VIDEOS DATASET FUNC CALLING         ##

if __name__ == "__main__":
    root_path = "TestDataset"  # Replace with your dataset root path
    
    data_array = process_dataset(root_path)
    
    # Save the data array to a .npy file
    np.save('handsigns_data.npy', data_array)
    print("Data saved to handsigns_data.npy")
# Out:
# Processing handsigns:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing videos for handsign 0:   0%|          | 0/50 [00:00<?, ?it/s]C:\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
#
# Processing videos for handsign 0:   2%|▏         | 1/50 [00:03<03:03,  3.75s/it]
# Processing videos for handsign 0:   4%|▍         | 2/50 [00:06<02:40,  3.35s/it]
# Processing videos for handsign 0:   6%|▌         | 3/50 [00:09<02:29,  3.17s/it]
# Processing videos for handsign 0:   8%|▊         | 4/50 [00:12<02:21,  3.07s/it]
# Processing videos for handsign 0:  10%|█         | 5/50 [00:15<02:11,  2.93s/it]
# Processing videos for handsign 0:  12%|█▏        | 6/50 [00:18<02:08,  2.92s/it]
# Processing videos for handsign 0:  14%|█▍        | 7/50 [00:21<02:10,  3.04s/it]
# Processing videos for handsign 0:  16%|█▌        | 8/50 [00:24<02:08,  3.06s/it]
# Processing videos for handsign 0:  18%|█▊        | 9/50 [00:28<02:12,  3.24s/it]
# Processing videos for handsign 0:  20%|██        | 10/50 [00:31<02:14,  3.35s/it]
# Processing videos for handsign 0:  22%|██▏       | 11/50 [00:35<02:09,  3.32s/it]
# Processing videos for handsign 0:  24%|██▍       | 12/50 [00:38<02:04,  3.28s/it]
# Processing videos for handsign 0:  26%|██▌       | 13/50 [00:41<01:56,  3.15s/it]
# Processing videos for handsign 0:  28%|██▊       | 14/50 [00:44<01:53,  3.17s/it]
# Processing videos for handsign 0:  30%|███       | 15/50 [00:47<01:47,  3.06s/it]
# Processing videos for handsign 0:  32%|███▏      | 16/50 [00:50<01:43,  3.04s/it]
# Processing videos for handsign 0:  34%|███▍      | 17/50 [00:53<01:41,  3.09s/it]
# Processing videos for handsign 0:  36%|███▌      | 18/50 [00:56<01:38,  3.07s/it]
# Processing videos for handsign 0:  38%|███▊      | 19/50 [00:59<01:37,  3.16s/it]
# Processing videos for handsign 0:  40%|████      | 20/50 [01:03<01:35,  3.17s/it]
# Processing videos for handsign 0:  42%|████▏     | 21/50 [01:06<01:33,  3.21s/it]
# Processing videos for handsign 0:  44%|████▍     | 22/50 [01:09<01:29,  3.19s/it]
# Processing videos for handsign 0:  46%|████▌     | 23/50 [01:12<01:28,  3.27s/it]
# Processing videos for handsign 0:  48%|████▊     | 24/50 [01:16<01:25,  3.27s/it]
# Processing videos for handsign 0:  50%|█████     | 25/50 [01:19<01:21,  3.28s/it]
# Processing videos for handsign 0:  52%|█████▏    | 26/50 [01:22<01:16,  3.18s/it]
# Processing videos for handsign 0:  54%|█████▍    | 27/50 [01:25<01:12,  3.13s/it]
# Processing videos for handsign 0:  56%|█████▌    | 28/50 [01:28<01:09,  3.17s/it]
# Processing videos for handsign 0:  58%|█████▊    | 29/50 [01:31<01:04,  3.07s/it]
# Processing videos for handsign 0:  60%|██████    | 30/50 [01:34<01:00,  3.04s/it]
# Processing videos for handsign 0:  62%|██████▏   | 31/50 [01:37<00:56,  2.96s/it]
# Processing videos for handsign 0:  64%|██████▍   | 32/50 [01:40<00:53,  2.95s/it]
# Processing videos for handsign 0:  66%|██████▌   | 33/50 [01:43<00:51,  3.02s/it]
# Processing videos for handsign 0:  68%|██████▊   | 34/50 [01:46<00:49,  3.09s/it]
# Processing videos for handsign 0:  70%|███████   | 35/50 [01:49<00:45,  3.01s/it]
# Processing videos for handsign 0:  72%|███████▏  | 36/50 [01:52<00:41,  2.94s/it]
# Processing videos for handsign 0:  74%|███████▍  | 37/50 [01:55<00:37,  2.89s/it]
# Processing videos for handsign 0:  76%|███████▌  | 38/50 [01:57<00:34,  2.87s/it]
# Processing videos for handsign 0:  78%|███████▊  | 39/50 [02:00<00:32,  2.92s/it]
# Processing videos for handsign 0:  80%|████████  | 40/50 [02:03<00:28,  2.86s/it]
# Processing videos for handsign 0:  82%|████████▏ | 41/50 [02:06<00:26,  2.96s/it]
# Processing videos for handsign 0:  84%|████████▍ | 42/50 [02:09<00:23,  2.91s/it]
# Processing videos for handsign 0:  86%|████████▌ | 43/50 [02:12<00:20,  2.86s/it]
# Processing videos for handsign 0:  88%|████████▊ | 44/50 [02:15<00:16,  2.83s/it]
# Processing videos for handsign 0:  90%|█████████ | 45/50 [02:18<00:14,  2.91s/it]
# Processing videos for handsign 0:  92%|█████████▏| 46/50 [02:21<00:11,  2.99s/it]
# Processing videos for handsign 0:  94%|█████████▍| 47/50 [02:24<00:08,  2.94s/it]
# Processing videos for handsign 0:  96%|█████████▌| 48/50 [02:27<00:05,  2.92s/it]
# Processing videos for handsign 0:  98%|█████████▊| 49/50 [02:29<00:02,  2.84s/it]
# Processing videos for handsign 0: 100%|██████████| 50/50 [02:32<00:00,  2.82s/it]
# Processing handsigns: 100%|██████████| 4/4 [02:32<00:00, 38.12s/it]
# Warning: Directory TestDataset\handsign_2 does not exist. Skipping.
# Warning: Directory TestDataset\handsign_3 does not exist. Skipping.
# Warning: Directory TestDataset\handsign_4 does not exist. Skipping.
# Data saved to handsigns_data.npy

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Flatten, TimeDistributed, MaxPooling1D
from tensorflow.keras.optimizers import Adam

# Define the CNN-LSTM Hybrid model
def create_cnn_lstm_model(input_shape, num_classes):
    model = Sequential()

    # TimeDistributed Conv1D for processing spatial features of each frame
    model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=input_shape))
    model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
    model.add(TimeDistributed(Dropout(0.3)))

    # Flatten the TimeDistributed output for LSTM input
    model.add(TimeDistributed(Flatten()))

    # LSTM layer to capture temporal dependencies
    model.add(LSTM(64, return_sequences=False))  # return_sequences=False since we want final output only
    
    # Fully connected layers
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))  # num_classes = number of hand signs

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Assuming input_shape = (num_frames, num_landmarks * 3), adjust accordingly based on your data processing
input_shape = (30, 51 * 3)  # Example: 30 frames, 51 landmarks (3D coordinates for each landmark)
num_classes = 4  # Adjust based on the number of hand signs in your dataset

# Build the model
cnn_lstm_model = create_cnn_lstm_model(input_shape, num_classes)
cnn_lstm_model.summary()

# %%
##          MODEL DEFINITION            ##

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Reshape, Input

# New input shape after reshaping
new_input_shape = (frames_per_video, num_landmarks * num_coordinates)

model = Sequential([
    # Input layer with the original shape
    Input(shape=(frames_per_video, num_landmarks, num_coordinates)),
    
    # Reshape layer to convert input shape from (30, 51, 3) to (30, 153)
    Reshape((frames_per_video, num_landmarks * num_coordinates)),
    
    # LSTM layers
    LSTM(64, return_sequences=True),
    LSTM(64),
    
    # Fully connected layers
    Dense(128, activation='relu'),
    Dense(num_handsigns, activation='softmax')  # Assuming 60 handsigns
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#model.summary()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Assuming X_train, y_train, X_val, y_val are your training and validation data
# X_train shape: (num_samples, num_frames, num_landmarks * 3)
# y_train shape: (num_samples, num_classes) - one-hot encoded labels

# Define callbacks
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# Train the model
history = cnn_lstm_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,  # Set based on your dataset size
    batch_size=32,  # Adjust as needed
    callbacks=[checkpoint, early_stopping],
    verbose=1
)

# Save the final model
cnn_lstm_model.save('cnn_lstm_model_final.h5')

# %%
##          MODEL TRAINING          ##

# Load the data from the .npy file
data_array = np.load('handsigns_data.npy')

# X remains unchanged
X = data_array  # Shape: (60, 50, 30, 51, 3)

# Create labels for each handsign (0 to num_handsigns-1)
# This creates a label for each hand sign, repeated for each video
y = np.repeat(np.arange(num_handsigns), videos_per_handsign)
y = y.reshape(num_handsigns, videos_per_handsign)  # Shape: (60, 50)

# Split data into training and validation sets
from sklearn.model_selection import train_test_split

# We need to split along the first two axes (hand signs and videos)
train_indices, val_indices = train_test_split(
    np.arange(num_handsigns), 
    test_size=0.2, 
    random_state=42
)

X_train = X[train_indices]
X_val = X[val_indices]
y_train = y[train_indices]
y_val = y[val_indices]

# Reshape X_train and X_val for the model
X_train = X_train.reshape(-1, frames_per_video, num_landmarks, num_coordinates)
X_val = X_val.reshape(-1, frames_per_video, num_landmarks, num_coordinates)

# Flatten y_train and y_val
y_train = y_train.flatten()
y_val = y_val.flatten()

# Train the model
history = model.fit(X_train, y_train, epochs=15, batch_size=10, validation_data=(X_val, y_val))

# Save the trained model
model.save('handsigns_model.h5')

# Optionally, save the training history
import pickle
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)
    
    

##          TRAINING HISTORY ANALYSIS           ##
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()
# If you saved the history to a file, load it first:
# import pickle
# with open('training_history.pkl', 'rb') as f:
#     history = pickle.load(f)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# If you want to save the plot instead of displaying it:
# plt.savefig('training_history.png')
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4168 - loss: 1.2188 - val_accuracy: 0.0000e+00 - val_loss: 2.1872
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3570 - loss: 1.2172 - val_accuracy: 0.0000e+00 - val_loss: 2.1996
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2691 - loss: 1.2158 - val_accuracy: 0.0000e+00 - val_loss: 2.2119
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3751 - loss: 1.2142 - val_accuracy: 0.0000e+00 - val_loss: 2.2241
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2788 - loss: 1.2127 - val_accuracy: 0.0000e+00 - val_loss: 2.2362
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2958 - loss: 1.2113 - val_accuracy: 0.0000e+00 - val_loss: 2.2483
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3415 - loss: 1.2098 - val_accuracy: 0.0000e+00 - val_loss: 2.2603
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2125 - loss: 1.2085 - val_accuracy: 0.0000e+00 - val_loss: 2.2723
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3297 - loss: 1.2071 - val_accuracy: 0.0000e+00 - val_loss: 2.2842
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2927 - loss: 1.2057 - val_accuracy: 0.0000e+00 - val_loss: 2.2960
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3112 - loss: 1.2044 - val_accuracy: 0.0000e+00 - val_loss: 2.3078
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3269 - loss: 1.2031 - val_accuracy: 0.0000e+00 - val_loss: 2.3195
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3705 - loss: 1.2016 - val_accuracy: 0.0000e+00 - val_loss: 2.3312
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3777 - loss: 1.2004 - val_accuracy: 0.0000e+00 - val_loss: 2.3428
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4247 - loss: 1.1991 - val_accuracy: 0.0000e+00 - val_loss: 2.3544
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
##          SINGLE VIDEO PREDICTION TEST         ##

def predict_handsign(video_path, model):
    # Process the video
    video_data = process_video(video_path)
    
    # Reshape the data to match the model input shape (Add batch dimension for single video prediction, this is necessary)
    video_data = video_data.reshape(1, frames_per_video, num_landmarks, num_coordinates)
    
    # Make prediction
    prediction = model.predict(video_data)
    predicted_class = np.argmax(prediction)
    confidence = prediction[0][predicted_class]
    
    return predicted_class, confidence

# Optional: Create a mapping of class indices to hand sign names
handsign_names = {
    0: "HandSign_1",
    1: "HandSign_2",
    2: "HandSign_3",
    3: "HandSign_4",
    # ... add more as needed
}

if __name__ == "__main__":
    # Load the trained model
    model = tf.keras.models.load_model('handsigns_model.h5')
    
    # Specify the path to your video
    video_path = "../modelTestingAndExecution/testData/handsign_4/WIN_20240720_18_03_50_Pro.mp4"
    """
    # Predict the hand sign
    predicted_class, confidence = predict_handsign(video_path, model)
    """
    """
    # Get the name of the predicted hand sign (if mapping is provided)
    predicted_handsign = handsign_names.get(predicted_class, f"HandSign_{predicted_class}")
    
    # Print the result
    print(f"Predicted Hand Sign: {predicted_handsign}")
    print(f"Confidence: {confidence:.2f}")
    """
    
    # Optionally, you can add code here to process multiple videos in a directory
    # For example:
    
    test_directory = "../modelTestingAndExecution/testData/single videos"
    for video_file in os.listdir(test_directory):
        if video_file.endswith(('.mp4', '.avi', '.mov')):
            video_path = os.path.join(test_directory, video_file)
            predicted_class, confidence = predict_handsign(video_path, model)
            predicted_handsign = handsign_names.get(predicted_class, f"HandSign_{predicted_class}")
            print(f"Video: {video_file}")
            print(f"Predicted Hand Sign: {predicted_handsign}")
            print(f"Confidence: {confidence:.2f}")
            print("--------------------")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# Video: #004WIN_20240720_18_03_50_Pro.mp4
# Predicted Hand Sign: HandSign_1
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Video: #handsign_02_01.mp4
# Predicted Hand Sign: HandSign_3
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Video: #handsign_02_02.mp4
# Predicted Hand Sign: HandSign_1
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Video: 001_005_004.mp4
# Predicted Hand Sign: HandSign_1
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Video: 001_008_003.mp4
# Predicted Hand Sign: HandSign_1
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Video: 002_007_002.mp4
# Predicted Hand Sign: HandSign_3
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Video: 002_009_003.mp4
# Predicted Hand Sign: HandSign_3
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Video: 003_007_002.mp4
# Predicted Hand Sign: HandSign_3
# Confidence: 1.00
# --------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Video: 003_008_004.mp4
# Predicted Hand Sign: HandSign_3
# Confidence: 1.00
# --------------------

# %%
##          MODEL TESTING          ##

import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

def load_and_preprocess_test_data(test_data_path):
    # Reuse the process_dataset function
    test_data = process_dataset(test_data_path)
    
    # Reshape the data to match the model input shape
    X_test = test_data.reshape(-1, frames_per_video, num_landmarks, num_coordinates)
    y_test = np.repeat(np.arange(num_handsigns), videos_per_handsign)
    
    return X_test, y_test

def evaluate_model(model, X_test, y_test):
    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    
    # Get predictions
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    # Generate classification report
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred_classes))
    
    return y_pred_classes

def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

def visualize_misclassifications(X_test, y_test, y_pred, num_samples=5):
    misclassified = np.where(y_test != y_pred)[0]
    np.random.shuffle(misclassified)
    
    for i in range(min(num_samples, len(misclassified))):
        idx = misclassified[i]
        plt.figure(figsize=(10, 5))
        
        # Plot a representation of the hand sign (e.g., first frame landmarks)
        plt.subplot(1, 2, 1)
        plt.scatter(X_test[idx, 0, :, 0], X_test[idx, 0, :, 1])
        plt.title(f"True: {y_test[idx]}, Predicted: {y_pred[idx]}")
        plt.xlabel("X coordinate")
        plt.ylabel("Y coordinate")
        
        # Plot the confidence scores for each class
        plt.subplot(1, 2, 2)
        confidence_scores = model.predict(X_test[idx:idx+1])[0]
        plt.bar(range(num_handsigns), confidence_scores)
        plt.title("Confidence Scores")
        plt.xlabel("Hand Sign Class")
        plt.ylabel("Confidence")
        
        plt.tight_layout()
        plt.show()

if __name__ == "__main__":
    # Load the trained model
    model = tf.keras.models.load_model('handsigns_model.h5')
    
    # Load and preprocess test data
    test_data_path = "../modelTestingAndExecution/testData"  # Replace with your test dataset path
    X_test, y_test = load_and_preprocess_test_data(test_data_path)
    
    # Evaluate the model
    y_pred = evaluate_model(model, X_test, y_test)
    
    # Plot confusion matrix
    plot_confusion_matrix(y_test, y_pred)
    
    # Visualize some misclassifications
    visualize_misclassifications(X_test, y_test, y_pred)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Processing handsigns: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Warning: Directory ../modelTestingAndExecution/testData\handsign_1 does not exist. Skipping.
# Warning: Directory ../modelTestingAndExecution/testData\handsign_2 does not exist. Skipping.
# Warning: Directory ../modelTestingAndExecution/testData\handsign_3 does not exist. Skipping.
# Warning: Directory ../modelTestingAndExecution/testData\handsign_4 does not exist. Skipping.
# Test Loss: 1.4874
# Test Accuracy: 0.2500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40        50
#            1       0.00      0.00      0.00        50
#            2       0.00      0.00      0.00        50
#            3       0.00      0.00      0.00        50
#
#     accuracy                           0.25       200
#    macro avg       0.06      0.25      0.10       200
# weighted avg       0.06      0.25      0.10       200
# C:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
